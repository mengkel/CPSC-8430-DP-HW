# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import Subset
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as utils
from IPython.display import HTML
import time
from torchvision import models
import torch.nn.functional as F
from scipy import linalg

# %%
dataset = datasets.CIFAR10(root="/home/mengkel/GAN/CIFAR10data", download=False,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=32,
                                         shuffle=True, num_workers=2)

device = torch.device("cuda")

# %%
torch.manual_seed(2020)
real_batch = next(iter(dataloader))
plt.figure(figsize=(10,10))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            # Dis_net(in_channels, out_channels, kernel_size, stride, padding)
            self.Dis_net(features_d, features_d * 2, 4, 2, 1),
            self.Dis_net(features_d * 2, features_d * 4, 4, 2, 1),
            self.Dis_net(features_d * 4, features_d * 8, 4, 2, 1),
            # After all _block img output is 4x4 (Conv2d below makes into 1x1)
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
        )

    def Dis_net(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.InstanceNorm2d(out_channels, affine=True),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            # Input: N x channels_noise x 1 x 1
            self.Gen_net(channels_noise, features_g * 16, 4, 1, 0),  # img: 4x4
            self.Gen_net(features_g * 16, features_g * 8, 4, 2, 1),  # img: 8x8
            self.Gen_net(features_g * 8, features_g * 4, 4, 2, 1),  # img: 16x16
            self.Gen_net(features_g * 4, features_g * 2, 4, 2, 1),  # img: 32x32
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            # Output: N x channels_img x 64 x 64
            nn.Tanh(),
        )

    def Gen_net(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
def initialize_weights(model):
    # Initializes weights according to the DCGAN paper
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
class InceptionV3(nn.Module):
    """Pretrained InceptionV3 network returning feature maps"""

    # Index of default block of inception to return,
    # corresponds to output of final average pooling
    DEFAULT_BLOCK_INDEX = 3

    # Maps feature dimensionality to their output blocks indices
    BLOCK_INDEX_BY_DIM = {
        64: 0,
        192: 1,
        768: 2,
        2048: 3
    }

    def __init__(self,
                 output_blocks=[DEFAULT_BLOCK_INDEX],
                 resize_input=True,
                 normalize_input=True,
                 requires_grad=False):
        
        super(InceptionV3, self).__init__()

        self.resize_input = resize_input
        self.normalize_input = normalize_input
        self.output_blocks = sorted(output_blocks)
        self.last_needed_block = max(output_blocks)

        assert self.last_needed_block <= 3, \
            'Last possible output block index is 3'

        self.blocks = nn.ModuleList()

        
        inception = models.inception_v3(pretrained=True)

        # Block 0: input to maxpool1
        block0 = [
            inception.Conv2d_1a_3x3,
            inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2)
        ]
        self.blocks.append(nn.Sequential(*block0))

        # Block 1: maxpool1 to maxpool2
        if self.last_needed_block >= 1:
            block1 = [
                inception.Conv2d_3b_1x1,
                inception.Conv2d_4a_3x3,
                nn.MaxPool2d(kernel_size=3, stride=2)
            ]
            self.blocks.append(nn.Sequential(*block1))

        # Block 2: maxpool2 to aux classifier
        if self.last_needed_block >= 2:
            block2 = [
                inception.Mixed_5b,
                inception.Mixed_5c,
                inception.Mixed_5d,
                inception.Mixed_6a,
                inception.Mixed_6b,
                inception.Mixed_6c,
                inception.Mixed_6d,
                inception.Mixed_6e,
            ]
            self.blocks.append(nn.Sequential(*block2))

        # Block 3: aux classifier to final avgpool
        if self.last_needed_block >= 3:
            block3 = [
                inception.Mixed_7a,
                inception.Mixed_7b,
                inception.Mixed_7c,
                nn.AdaptiveAvgPool2d(output_size=(1, 1))
            ]
            self.blocks.append(nn.Sequential(*block3))

        for param in self.parameters():
            param.requires_grad = requires_grad

    def forward(self, inp):
        outp = []
        x = inp

        if self.resize_input:
            x = F.interpolate(x,
                              size=(299, 299),
                              mode='bilinear',
                              align_corners=False)

        if self.normalize_input:
            x = 2 * x - 1  # Scale from range (0, 1) to range (-1, 1)

        for idx, block in enumerate(self.blocks):
            x = block(x)
            if idx in self.output_blocks:
                outp.append(x)

            if idx == self.last_needed_block:
                break

        return outp
    
block_idx = InceptionV3.BLOCK_INDEX_BY_DIM[2048]
model = InceptionV3([block_idx])
model=model.cuda()
# Out:
# /home/mengkel/.conda/envs/skln/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/mengkel/.conda/envs/skln/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def calculate_activation_statistics(images, model, batch_size=128, dims=2048, cuda=False):
    model.eval()
    act=np.empty((len(images), dims))
    
    if cuda:
        batch=images.cuda()
    else:
        batch=images
    pred = model(batch)[0]
    if pred.size(2) != 1 or pred.size(3) != 1:
        pred = adaptive_avg_pool2d(pred, output_size=(1, 1))

    act= pred.cpu().data.numpy().reshape(pred.size(0), -1)
    
    mu = np.mean(act, axis=0)
    sigma = np.cov(act, rowvar=False)
    return mu, sigma

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)

    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)

    assert mu1.shape == mu2.shape, \
        'Training and test mean vectors have different lengths'
    assert sigma1.shape == sigma2.shape, \
        'Training and test covariances have different dimensions'

    diff = mu1 - mu2

    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        msg = ('fid calculation produces singular product; '
               'adding %s to diagonal of cov estimates') % eps
        print(msg)
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))

    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real

    tr_covmean = np.trace(covmean)

    return (diff.dot(diff) + np.trace(sigma1) +
            np.trace(sigma2) - 2 * tr_covmean)

def calculate_fretchet(images_real,images_fake,model):
    mu_1,std_1 = calculate_activation_statistics(images_real,model,cuda=True)
    mu_2,std_2 = calculate_activation_statistics(images_fake,model,cuda=True)
    fid_value = calculate_frechet_distance(mu_1, std_1, mu_2, std_2)
    return fid_value

# %%
lr = 5e-5
Z_DIM = 128
num_epochs = 20
WEIGHT_CLIP = 0.01

# %%
gen = Generator(Z_DIM, channels_img = 3, features_g = 64).to(device)
critic = Discriminator(channels_img = 3, features_d = 64).to(device)
initialize_weights(gen)
initialize_weights(critic)

# %%
opt_gen = optim.RMSprop(gen.parameters(), lr = lr)
opt_critic = optim.RMSprop(critic.parameters(), lr = lr)

fixed_noise = torch.randn(32, Z_DIM, 1, 1).to(device)
step = 0

gen.train()
critic.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#   )
# )

# %%
GenLoss = []
DiscLoss = []
img_list = []
fretchet_distances = []
iters = 0

for epoch in range(num_epochs):
    # Target labels not needed! <3 unsupervised
    for batch_idx, (data, _) in enumerate(dataloader):
        data = data.to(device)
        cur_batch_size = data.shape[0]

        # Train Critic: max E[critic(real)] - E[critic(fake)]
        for _ in range(5): # 5 critic iterations
            noise = torch.randn(cur_batch_size, Z_DIM, 1, 1).to(device)
            fake = gen(noise)
            critic_real = critic(data).reshape(-1)
            critic_fake = critic(fake).reshape(-1)
            loss_critic = -(torch.mean(critic_real) - torch.mean(critic_fake))
            critic.zero_grad()
            loss_critic.backward(retain_graph=True)
            opt_critic.step()

            # clip critic weights between -0.01, 0.01
            for p in critic.parameters():
                p.data.clamp_(-WEIGHT_CLIP, WEIGHT_CLIP)

        # Train Generator: max E[critic(gen_fake)] <-> min -E[critic(gen_fake)]
        gen_fake = critic(fake).reshape(-1)
        loss_gen = -torch.mean(gen_fake)
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()

        # Print losses occasionally
        if batch_idx % 100 == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(dataloader)} \
                  Loss Discriminator: {loss_critic:.3f}, loss Generator: {loss_gen:.3f}"
            )
        #saving the losses for every 100 batch
        GenLoss.append(loss_gen.detach().cpu())
        DiscLoss.append(loss_critic.detach().cpu())
        
        # Check how the generator is doing by saving G's output on fixed_noise
        if (iters % 500 == 0) or ((epoch == num_epochs) and (batch_idx == len(dataloader)-1)):
            with torch.no_grad():
                fake = gen(fixed_noise).detach().cpu()
            img_list.append(utils.make_grid(fake, padding=2, normalize=True))
            
        iters += 1
    fretchet_dist = calculate_fretchet(data, fake, model)
    fretchet_distances.append(fretchet_dist)
    print('Fretchet Distance: ', fretchet_dist)
# Out:
# Epoch [0/20] Batch 0/1563                   Loss Discriminator: -0.021, loss Generator: 0.017
# Epoch [0/20] Batch 100/1563                   Loss Discriminator: -1.367, loss Generator: 0.687
# Epoch [0/20] Batch 200/1563                   Loss Discriminator: -1.503, loss Generator: 0.757
# Epoch [0/20] Batch 300/1563                   Loss Discriminator: -1.549, loss Generator: 0.774
# Epoch [0/20] Batch 400/1563                   Loss Discriminator: -1.548, loss Generator: 0.774
# Epoch [0/20] Batch 500/1563                   Loss Discriminator: -1.524, loss Generator: 0.767
# Epoch [0/20] Batch 600/1563                   Loss Discriminator: -1.513, loss Generator: 0.758
# Epoch [0/20] Batch 700/1563                   Loss Discriminator: -1.487, loss Generator: 0.754
# Epoch [0/20] Batch 800/1563                   Loss Discriminator: -1.470, loss Generator: 0.728
# Epoch [0/20] Batch 900/1563                   Loss Discriminator: -1.444, loss Generator: 0.734
# Epoch [0/20] Batch 1000/1563                   Loss Discriminator: -1.358, loss Generator: 0.663
# Epoch [0/20] Batch 1100/1563                   Loss Discriminator: -1.241, loss Generator: 0.686
# Epoch [0/20] Batch 1200/1563                   Loss Discriminator: -1.400, loss Generator: 0.708
# Epoch [0/20] Batch 1300/1563                   Loss Discriminator: -1.271, loss Generator: 0.641
# Epoch [0/20] Batch 1400/1563                   Loss Discriminator: -1.178, loss Generator: 0.638
# Epoch [0/20] Batch 1500/1563                   Loss Discriminator: -1.192, loss Generator: 0.643
# Fretchet Distance:  328.3537213671848
# Epoch [1/20] Batch 0/1563                   Loss Discriminator: -1.172, loss Generator: 0.569
# Epoch [1/20] Batch 100/1563                   Loss Discriminator: -1.083, loss Generator: 0.543
# Epoch [1/20] Batch 200/1563                   Loss Discriminator: -1.230, loss Generator: 0.630
# Epoch [1/20] Batch 300/1563                   Loss Discriminator: -1.064, loss Generator: 0.475
# Epoch [1/20] Batch 400/1563                   Loss Discriminator: -1.041, loss Generator: 0.654
# Epoch [1/20] Batch 500/1563                   Loss Discriminator: -1.091, loss Generator: 0.664
# Epoch [1/20] Batch 600/1563                   Loss Discriminator: -1.064, loss Generator: 0.504
# Epoch [1/20] Batch 700/1563                   Loss Discriminator: -0.997, loss Generator: 0.427
# Epoch [1/20] Batch 800/1563                   Loss Discriminator: -1.136, loss Generator: 0.558
# Epoch [1/20] Batch 900/1563                   Loss Discriminator: -0.959, loss Generator: 0.424
# Epoch [1/20] Batch 1000/1563                   Loss Discriminator: -0.948, loss Generator: 0.656
# Epoch [1/20] Batch 1100/1563                   Loss Discriminator: -1.089, loss Generator: 0.657
# Epoch [1/20] Batch 1200/1563                   Loss Discriminator: -1.020, loss Generator: 0.461
# Epoch [1/20] Batch 1300/1563                   Loss Discriminator: -0.938, loss Generator: 0.651
# Epoch [1/20] Batch 1400/1563                   Loss Discriminator: -0.949, loss Generator: 0.386
# Epoch [1/20] Batch 1500/1563                   Loss Discriminator: -1.060, loss Generator: 0.599
# Fretchet Distance:  303.0830987190561
# Epoch [2/20] Batch 0/1563                   Loss Discriminator: -1.016, loss Generator: 0.457
# Epoch [2/20] Batch 100/1563                   Loss Discriminator: -0.965, loss Generator: 0.443
# Epoch [2/20] Batch 200/1563                   Loss Discriminator: -0.806, loss Generator: 0.325
# Epoch [2/20] Batch 300/1563                   Loss Discriminator: -1.044, loss Generator: 0.493
# Epoch [2/20] Batch 400/1563                   Loss Discriminator: -1.109, loss Generator: 0.565
# Epoch [2/20] Batch 500/1563                   Loss Discriminator: -0.917, loss Generator: 0.391
# Epoch [2/20] Batch 600/1563                   Loss Discriminator: -0.977, loss Generator: 0.480
# Epoch [2/20] Batch 700/1563                   Loss Discriminator: -0.828, loss Generator: 0.618
# Epoch [2/20] Batch 800/1563                   Loss Discriminator: -1.025, loss Generator: 0.481
# Epoch [2/20] Batch 900/1563                   Loss Discriminator: -0.769, loss Generator: 0.347
# Epoch [2/20] Batch 1000/1563                   Loss Discriminator: -0.904, loss Generator: 0.653
# Epoch [2/20] Batch 1100/1563                   Loss Discriminator: -0.960, loss Generator: 0.500
# Epoch [2/20] Batch 1200/1563                   Loss Discriminator: -1.069, loss Generator: 0.626
# Epoch [2/20] Batch 1300/1563                   Loss Discriminator: -1.042, loss Generator: 0.513
# Epoch [2/20] Batch 1400/1563                   Loss Discriminator: -0.999, loss Generator: 0.615
# Epoch [2/20] Batch 1500/1563                   Loss Discriminator: -0.966, loss Generator: 0.613
# Fretchet Distance:  296.6003356235903
# Epoch [3/20] Batch 0/1563                   Loss Discriminator: -1.015, loss Generator: 0.455
# Epoch [3/20] Batch 100/1563                   Loss Discriminator: -0.907, loss Generator: 0.651
# Epoch [3/20] Batch 200/1563                   Loss Discriminator: -0.770, loss Generator: 0.471
# Epoch [3/20] Batch 300/1563                   Loss Discriminator: -0.890, loss Generator: 0.347
# Epoch [3/20] Batch 400/1563                   Loss Discriminator: -0.860, loss Generator: 0.251
# Epoch [3/20] Batch 500/1563                   Loss Discriminator: -0.980, loss Generator: 0.623
# Epoch [3/20] Batch 600/1563                   Loss Discriminator: -0.945, loss Generator: 0.452
# Epoch [3/20] Batch 700/1563                   Loss Discriminator: -0.977, loss Generator: 0.402
# Epoch [3/20] Batch 800/1563                   Loss Discriminator: -1.035, loss Generator: 0.595
# Epoch [3/20] Batch 900/1563                   Loss Discriminator: -0.949, loss Generator: 0.426
# Epoch [3/20] Batch 1000/1563                   Loss Discriminator: -0.829, loss Generator: 0.630
# Epoch [3/20] Batch 1100/1563                   Loss Discriminator: -0.901, loss Generator: 0.322
# Epoch [3/20] Batch 1200/1563                   Loss Discriminator: -0.955, loss Generator: 0.445
# Epoch [3/20] Batch 1300/1563                   Loss Discriminator: -0.924, loss Generator: 0.640
# Epoch [3/20] Batch 1400/1563                   Loss Discriminator: -0.959, loss Generator: 0.557
# Epoch [3/20] Batch 1500/1563                   Loss Discriminator: -0.921, loss Generator: 0.328
# Fretchet Distance:  282.8661993378895
# Epoch [4/20] Batch 0/1563                   Loss Discriminator: -0.924, loss Generator: 0.530
# Epoch [4/20] Batch 100/1563                   Loss Discriminator: -0.950, loss Generator: 0.604
# Epoch [4/20] Batch 200/1563                   Loss Discriminator: -0.920, loss Generator: 0.635
# Epoch [4/20] Batch 300/1563                   Loss Discriminator: -0.898, loss Generator: 0.436
# Epoch [4/20] Batch 400/1563                   Loss Discriminator: -0.844, loss Generator: 0.354
# Epoch [4/20] Batch 500/1563                   Loss Discriminator: -0.994, loss Generator: 0.600
# Epoch [4/20] Batch 600/1563                   Loss Discriminator: -0.871, loss Generator: 0.221
# Epoch [4/20] Batch 700/1563                   Loss Discriminator: -0.855, loss Generator: 0.330
# Epoch [4/20] Batch 800/1563                   Loss Discriminator: -0.849, loss Generator: 0.628
# Epoch [4/20] Batch 900/1563                   Loss Discriminator: -0.719, loss Generator: 0.259
# Epoch [4/20] Batch 1000/1563                   Loss Discriminator: -0.906, loss Generator: 0.635
# Epoch [4/20] Batch 1100/1563                   Loss Discriminator: -0.928, loss Generator: 0.446
# Epoch [4/20] Batch 1200/1563                   Loss Discriminator: -0.750, loss Generator: 0.626
# Epoch [4/20] Batch 1300/1563                   Loss Discriminator: -0.757, loss Generator: 0.616
# Epoch [4/20] Batch 1400/1563                   Loss Discriminator: -0.883, loss Generator: 0.362
# Epoch [4/20] Batch 1500/1563                   Loss Discriminator: -0.812, loss Generator: 0.574
# Fretchet Distance:  289.6760225029625
# Epoch [5/20] Batch 0/1563                   Loss Discriminator: -0.846, loss Generator: 0.340
# Epoch [5/20] Batch 100/1563                   Loss Discriminator: -0.876, loss Generator: 0.422
# Epoch [5/20] Batch 200/1563                   Loss Discriminator: -0.821, loss Generator: 0.301
# Epoch [5/20] Batch 300/1563                   Loss Discriminator: -0.759, loss Generator: 0.614
# Epoch [5/20] Batch 400/1563                   Loss Discriminator: -0.715, loss Generator: 0.172
# Epoch [5/20] Batch 500/1563                   Loss Discriminator: -0.799, loss Generator: 0.592
# Epoch [5/20] Batch 600/1563                   Loss Discriminator: -0.716, loss Generator: 0.173
# Epoch [5/20] Batch 700/1563                   Loss Discriminator: -0.769, loss Generator: 0.311
# Epoch [5/20] Batch 800/1563                   Loss Discriminator: -0.671, loss Generator: 0.148
# Epoch [5/20] Batch 900/1563                   Loss Discriminator: -0.816, loss Generator: 0.515
# Epoch [5/20] Batch 1000/1563                   Loss Discriminator: -0.705, loss Generator: 0.533
# Epoch [5/20] Batch 1100/1563                   Loss Discriminator: -0.832, loss Generator: 0.272
# Epoch [5/20] Batch 1200/1563                   Loss Discriminator: -0.879, loss Generator: 0.617
# Epoch [5/20] Batch 1300/1563                   Loss Discriminator: -0.742, loss Generator: 0.580
# Epoch [5/20] Batch 1400/1563                   Loss Discriminator: -0.668, loss Generator: 0.563
# Epoch [5/20] Batch 1500/1563                   Loss Discriminator: -0.742, loss Generator: 0.263
# Fretchet Distance:  313.9681616381223
# Epoch [6/20] Batch 0/1563                   Loss Discriminator: -0.774, loss Generator: 0.283
# Epoch [6/20] Batch 100/1563                   Loss Discriminator: -0.792, loss Generator: 0.228
# Epoch [6/20] Batch 200/1563                   Loss Discriminator: -0.745, loss Generator: 0.621
# Epoch [6/20] Batch 300/1563                   Loss Discriminator: -0.806, loss Generator: 0.417
# Epoch [6/20] Batch 400/1563                   Loss Discriminator: -0.619, loss Generator: 0.101
# Epoch [6/20] Batch 500/1563                   Loss Discriminator: -0.738, loss Generator: 0.293
# Epoch [6/20] Batch 600/1563                   Loss Discriminator: -0.832, loss Generator: 0.585
# Epoch [6/20] Batch 700/1563                   Loss Discriminator: -0.760, loss Generator: 0.461
# Epoch [6/20] Batch 800/1563                   Loss Discriminator: -0.724, loss Generator: 0.595
# Epoch [6/20] Batch 900/1563                   Loss Discriminator: -0.752, loss Generator: 0.145
# Epoch [6/20] Batch 1000/1563                   Loss Discriminator: -0.553, loss Generator: 0.595
# Epoch [6/20] Batch 1100/1563                   Loss Discriminator: -0.712, loss Generator: 0.580
# Epoch [6/20] Batch 1200/1563                   Loss Discriminator: -0.784, loss Generator: 0.266
# Epoch [6/20] Batch 1300/1563                   Loss Discriminator: -0.832, loss Generator: 0.526
# Epoch [6/20] Batch 1400/1563                   Loss Discriminator: -0.782, loss Generator: 0.187
# Epoch [6/20] Batch 1500/1563                   Loss Discriminator: -0.762, loss Generator: 0.384
# Fretchet Distance:  292.64591804474907
# Epoch [7/20] Batch 0/1563                   Loss Discriminator: -0.740, loss Generator: 0.277
# Epoch [7/20] Batch 100/1563                   Loss Discriminator: -0.657, loss Generator: 0.602
# Epoch [7/20] Batch 200/1563                   Loss Discriminator: -0.714, loss Generator: 0.396
# Epoch [7/20] Batch 300/1563                   Loss Discriminator: -0.663, loss Generator: 0.595
# Epoch [7/20] Batch 400/1563                   Loss Discriminator: -0.695, loss Generator: 0.586
# Epoch [7/20] Batch 500/1563                   Loss Discriminator: -0.685, loss Generator: 0.575
# Epoch [7/20] Batch 600/1563                   Loss Discriminator: -0.741, loss Generator: 0.621
# Epoch [7/20] Batch 700/1563                   Loss Discriminator: -0.810, loss Generator: 0.586
# Epoch [7/20] Batch 800/1563                   Loss Discriminator: -0.817, loss Generator: 0.459
# Epoch [7/20] Batch 900/1563                   Loss Discriminator: -0.711, loss Generator: 0.269
# Epoch [7/20] Batch 1000/1563                   Loss Discriminator: -0.781, loss Generator: 0.250
# Epoch [7/20] Batch 1100/1563                   Loss Discriminator: -0.760, loss Generator: 0.279
# Epoch [7/20] Batch 1200/1563                   Loss Discriminator: -0.786, loss Generator: 0.579
# Epoch [7/20] Batch 1300/1563                   Loss Discriminator: -0.748, loss Generator: 0.575
# Epoch [7/20] Batch 1400/1563                   Loss Discriminator: -0.671, loss Generator: 0.230
# Epoch [7/20] Batch 1500/1563                   Loss Discriminator: -0.644, loss Generator: 0.165
# Fretchet Distance:  304.82870725840246
# Epoch [8/20] Batch 0/1563                   Loss Discriminator: -0.711, loss Generator: 0.347
# Epoch [8/20] Batch 100/1563                   Loss Discriminator: -0.648, loss Generator: 0.170
# Epoch [8/20] Batch 200/1563                   Loss Discriminator: -0.611, loss Generator: 0.572
# Epoch [8/20] Batch 300/1563                   Loss Discriminator: -0.709, loss Generator: 0.236
# Epoch [8/20] Batch 400/1563                   Loss Discriminator: -0.481, loss Generator: 0.507
# Epoch [8/20] Batch 500/1563                   Loss Discriminator: -0.723, loss Generator: 0.517
# Epoch [8/20] Batch 600/1563                   Loss Discriminator: -0.606, loss Generator: 0.118
# Epoch [8/20] Batch 700/1563                   Loss Discriminator: -0.720, loss Generator: 0.546
# Epoch [8/20] Batch 800/1563                   Loss Discriminator: -0.720, loss Generator: 0.089
# Epoch [8/20] Batch 900/1563                   Loss Discriminator: -0.682, loss Generator: 0.577
# Epoch [8/20] Batch 1000/1563                   Loss Discriminator: -0.785, loss Generator: 0.208
# Epoch [8/20] Batch 1100/1563                   Loss Discriminator: -0.539, loss Generator: 0.107
# Epoch [8/20] Batch 1200/1563                   Loss Discriminator: -0.683, loss Generator: 0.164
# Epoch [8/20] Batch 1300/1563                   Loss Discriminator: -0.660, loss Generator: 0.162
# Epoch [8/20] Batch 1400/1563                   Loss Discriminator: -0.598, loss Generator: 0.049
# Epoch [8/20] Batch 1500/1563                   Loss Discriminator: -0.727, loss Generator: 0.497
# Fretchet Distance:  280.49606469234607
# Epoch [9/20] Batch 0/1563                   Loss Discriminator: -0.704, loss Generator: 0.142
# Epoch [9/20] Batch 100/1563                   Loss Discriminator: -0.696, loss Generator: 0.084
# Epoch [9/20] Batch 200/1563                   Loss Discriminator: -0.502, loss Generator: 0.534
# Epoch [9/20] Batch 300/1563                   Loss Discriminator: -0.680, loss Generator: 0.119
# Epoch [9/20] Batch 400/1563                   Loss Discriminator: -0.768, loss Generator: 0.490
# Epoch [9/20] Batch 500/1563                   Loss Discriminator: -0.588, loss Generator: 0.185
# Epoch [9/20] Batch 600/1563                   Loss Discriminator: -0.745, loss Generator: 0.578
# Epoch [9/20] Batch 700/1563                   Loss Discriminator: -0.549, loss Generator: 0.026
# Epoch [9/20] Batch 800/1563                   Loss Discriminator: -0.615, loss Generator: 0.541
# Epoch [9/20] Batch 900/1563                   Loss Discriminator: -0.643, loss Generator: 0.142
# Epoch [9/20] Batch 1000/1563                   Loss Discriminator: -0.725, loss Generator: 0.231
# Epoch [9/20] Batch 1100/1563                   Loss Discriminator: -0.638, loss Generator: 0.567
# Epoch [9/20] Batch 1200/1563                   Loss Discriminator: -0.656, loss Generator: 0.229
# Epoch [9/20] Batch 1300/1563                   Loss Discriminator: -0.674, loss Generator: 0.173
# Epoch [9/20] Batch 1400/1563                   Loss Discriminator: -0.731, loss Generator: 0.554
# Epoch [9/20] Batch 1500/1563                   Loss Discriminator: -0.728, loss Generator: 0.385
# Fretchet Distance:  282.3551941916237
# Epoch [10/20] Batch 0/1563                   Loss Discriminator: -0.720, loss Generator: 0.277
# Epoch [10/20] Batch 100/1563                   Loss Discriminator: -0.485, loss Generator: 0.023
# Epoch [10/20] Batch 200/1563                   Loss Discriminator: -0.632, loss Generator: 0.575
# Epoch [10/20] Batch 300/1563                   Loss Discriminator: -0.673, loss Generator: 0.098
# Epoch [10/20] Batch 400/1563                   Loss Discriminator: -0.738, loss Generator: 0.291
# Epoch [10/20] Batch 500/1563                   Loss Discriminator: -0.603, loss Generator: 0.135
# Epoch [10/20] Batch 600/1563                   Loss Discriminator: -0.695, loss Generator: 0.241
# Epoch [10/20] Batch 700/1563                   Loss Discriminator: -0.754, loss Generator: 0.341
# Epoch [10/20] Batch 800/1563                   Loss Discriminator: -0.589, loss Generator: 0.537
# Epoch [10/20] Batch 900/1563                   Loss Discriminator: -0.689, loss Generator: 0.199
# Epoch [10/20] Batch 1000/1563                   Loss Discriminator: -0.560, loss Generator: 0.545
# Epoch [10/20] Batch 1100/1563                   Loss Discriminator: -0.624, loss Generator: 0.556
# Epoch [10/20] Batch 1200/1563                   Loss Discriminator: -0.730, loss Generator: 0.581
# Epoch [10/20] Batch 1300/1563                   Loss Discriminator: -0.542, loss Generator: 0.089
# Epoch [10/20] Batch 1400/1563                   Loss Discriminator: -0.637, loss Generator: 0.263
# Epoch [10/20] Batch 1500/1563                   Loss Discriminator: -0.684, loss Generator: 0.154
# Fretchet Distance:  306.6154230717816
# Epoch [11/20] Batch 0/1563                   Loss Discriminator: -0.495, loss Generator: 0.530
# Epoch [11/20] Batch 100/1563                   Loss Discriminator: -0.637, loss Generator: 0.573
# Epoch [11/20] Batch 200/1563                   Loss Discriminator: -0.616, loss Generator: 0.160
# Epoch [11/20] Batch 300/1563                   Loss Discriminator: -0.599, loss Generator: 0.387
# Epoch [11/20] Batch 400/1563                   Loss Discriminator: -0.564, loss Generator: 0.540
# Epoch [11/20] Batch 500/1563                   Loss Discriminator: -0.529, loss Generator: 0.141
# Epoch [11/20] Batch 600/1563                   Loss Discriminator: -0.669, loss Generator: 0.593
# Epoch [11/20] Batch 700/1563                   Loss Discriminator: -0.558, loss Generator: 0.155
# Epoch [11/20] Batch 800/1563                   Loss Discriminator: -0.610, loss Generator: 0.598
# Epoch [11/20] Batch 900/1563                   Loss Discriminator: -0.556, loss Generator: 0.076
# Epoch [11/20] Batch 1000/1563                   Loss Discriminator: -0.737, loss Generator: 0.198
# Epoch [11/20] Batch 1100/1563                   Loss Discriminator: -0.539, loss Generator: 0.592
# Epoch [11/20] Batch 1200/1563                   Loss Discriminator: -0.578, loss Generator: 0.196
# Epoch [11/20] Batch 1300/1563                   Loss Discriminator: -0.501, loss Generator: 0.506
# Epoch [11/20] Batch 1400/1563                   Loss Discriminator: -0.636, loss Generator: 0.063
# Epoch [11/20] Batch 1500/1563                   Loss Discriminator: -0.613, loss Generator: 0.339
# Fretchet Distance:  275.9427730148825
# Epoch [12/20] Batch 0/1563                   Loss Discriminator: -0.624, loss Generator: 0.586
# Epoch [12/20] Batch 100/1563                   Loss Discriminator: -0.455, loss Generator: 0.486
# Epoch [12/20] Batch 200/1563                   Loss Discriminator: -0.609, loss Generator: 0.586
# Epoch [12/20] Batch 300/1563                   Loss Discriminator: -0.590, loss Generator: 0.062
# Epoch [12/20] Batch 400/1563                   Loss Discriminator: -0.678, loss Generator: 0.585
# Epoch [12/20] Batch 500/1563                   Loss Discriminator: -0.566, loss Generator: 0.439
# Epoch [12/20] Batch 600/1563                   Loss Discriminator: -0.518, loss Generator: 0.077
# Epoch [12/20] Batch 700/1563                   Loss Discriminator: -0.508, loss Generator: -0.049
# Epoch [12/20] Batch 800/1563                   Loss Discriminator: -0.594, loss Generator: 0.576
# Epoch [12/20] Batch 900/1563                   Loss Discriminator: -0.551, loss Generator: 0.560
# Epoch [12/20] Batch 1000/1563                   Loss Discriminator: -0.513, loss Generator: 0.096
# Epoch [12/20] Batch 1100/1563                   Loss Discriminator: -0.643, loss Generator: 0.574
# Epoch [12/20] Batch 1200/1563                   Loss Discriminator: -0.509, loss Generator: 0.549
# Epoch [12/20] Batch 1300/1563                   Loss Discriminator: -0.620, loss Generator: 0.454
# Epoch [12/20] Batch 1400/1563                   Loss Discriminator: -0.695, loss Generator: 0.294
# Epoch [12/20] Batch 1500/1563                   Loss Discriminator: -0.640, loss Generator: 0.457
# Fretchet Distance:  302.8007082916269
# Epoch [13/20] Batch 0/1563                   Loss Discriminator: -0.681, loss Generator: 0.401
# Epoch [13/20] Batch 100/1563                   Loss Discriminator: -0.537, loss Generator: -0.020
# Epoch [13/20] Batch 200/1563                   Loss Discriminator: -0.464, loss Generator: -0.089
# Epoch [13/20] Batch 300/1563                   Loss Discriminator: -0.606, loss Generator: 0.529
# Epoch [13/20] Batch 400/1563                   Loss Discriminator: -0.521, loss Generator: 0.511
# Epoch [13/20] Batch 500/1563                   Loss Discriminator: -0.407, loss Generator: 0.538
# Epoch [13/20] Batch 600/1563                   Loss Discriminator: -0.566, loss Generator: 0.572
# Epoch [13/20] Batch 700/1563                   Loss Discriminator: -0.615, loss Generator: 0.600
# Epoch [13/20] Batch 800/1563                   Loss Discriminator: -0.589, loss Generator: 0.165
# Epoch [13/20] Batch 900/1563                   Loss Discriminator: -0.670, loss Generator: 0.563
# Epoch [13/20] Batch 1000/1563                   Loss Discriminator: -0.614, loss Generator: 0.574
# Epoch [13/20] Batch 1100/1563                   Loss Discriminator: -0.638, loss Generator: 0.126
# Epoch [13/20] Batch 1200/1563                   Loss Discriminator: -0.586, loss Generator: 0.552
# Epoch [13/20] Batch 1300/1563                   Loss Discriminator: -0.686, loss Generator: 0.478
# Epoch [13/20] Batch 1400/1563                   Loss Discriminator: -0.647, loss Generator: -0.035
# Epoch [13/20] Batch 1500/1563                   Loss Discriminator: -0.654, loss Generator: 0.557
# Fretchet Distance:  309.43895200134915
# Epoch [14/20] Batch 0/1563                   Loss Discriminator: -0.500, loss Generator: 0.494
# Epoch [14/20] Batch 100/1563                   Loss Discriminator: -0.502, loss Generator: 0.525
# Epoch [14/20] Batch 200/1563                   Loss Discriminator: -0.568, loss Generator: -0.138
# Epoch [14/20] Batch 300/1563                   Loss Discriminator: -0.648, loss Generator: 0.428
# Epoch [14/20] Batch 400/1563                   Loss Discriminator: -0.439, loss Generator: 0.557
# Epoch [14/20] Batch 500/1563                   Loss Discriminator: -0.471, loss Generator: 0.163
# Epoch [14/20] Batch 600/1563                   Loss Discriminator: -0.521, loss Generator: -0.081
# Epoch [14/20] Batch 700/1563                   Loss Discriminator: -0.490, loss Generator: -0.000
# Epoch [14/20] Batch 800/1563                   Loss Discriminator: -0.594, loss Generator: 0.163
# Epoch [14/20] Batch 900/1563                   Loss Discriminator: -0.564, loss Generator: 0.521
# Epoch [14/20] Batch 1000/1563                   Loss Discriminator: -0.575, loss Generator: 0.188
# Epoch [14/20] Batch 1100/1563                   Loss Discriminator: -0.506, loss Generator: -0.068
# Epoch [14/20] Batch 1200/1563                   Loss Discriminator: -0.580, loss Generator: 0.575
# Epoch [14/20] Batch 1300/1563                   Loss Discriminator: -0.438, loss Generator: 0.161
# Epoch [14/20] Batch 1400/1563                   Loss Discriminator: -0.541, loss Generator: 0.536
# Epoch [14/20] Batch 1500/1563                   Loss Discriminator: -0.532, loss Generator: 0.108
# Fretchet Distance:  262.220344191624
# Epoch [15/20] Batch 0/1563                   Loss Discriminator: -0.572, loss Generator: 0.568
# Epoch [15/20] Batch 100/1563                   Loss Discriminator: -0.613, loss Generator: 0.177
# Epoch [15/20] Batch 200/1563                   Loss Discriminator: -0.628, loss Generator: 0.525
# Epoch [15/20] Batch 300/1563                   Loss Discriminator: -0.554, loss Generator: 0.012
# Epoch [15/20] Batch 400/1563                   Loss Discriminator: -0.399, loss Generator: 0.051
# Epoch [15/20] Batch 500/1563                   Loss Discriminator: -0.591, loss Generator: -0.035
# Epoch [15/20] Batch 600/1563                   Loss Discriminator: -0.679, loss Generator: 0.155
# Epoch [15/20] Batch 700/1563                   Loss Discriminator: -0.535, loss Generator: 0.538
# Epoch [15/20] Batch 800/1563                   Loss Discriminator: -0.630, loss Generator: 0.124
# Epoch [15/20] Batch 900/1563                   Loss Discriminator: -0.529, loss Generator: 0.514
# Epoch [15/20] Batch 1000/1563                   Loss Discriminator: -0.525, loss Generator: 0.468
# Epoch [15/20] Batch 1100/1563                   Loss Discriminator: -0.544, loss Generator: 0.559
# Epoch [15/20] Batch 1200/1563                   Loss Discriminator: -0.528, loss Generator: 0.542
# Epoch [15/20] Batch 1300/1563                   Loss Discriminator: -0.566, loss Generator: 0.023
# Epoch [15/20] Batch 1400/1563                   Loss Discriminator: -0.601, loss Generator: 0.021
# Epoch [15/20] Batch 1500/1563                   Loss Discriminator: -0.521, loss Generator: 0.534
# Fretchet Distance:  285.0655235967416
# Epoch [16/20] Batch 0/1563                   Loss Discriminator: -0.615, loss Generator: 0.411
# Epoch [16/20] Batch 100/1563                   Loss Discriminator: -0.433, loss Generator: 0.428
# Epoch [16/20] Batch 200/1563                   Loss Discriminator: -0.657, loss Generator: 0.244
# Epoch [16/20] Batch 300/1563                   Loss Discriminator: -0.395, loss Generator: 0.523
# Epoch [16/20] Batch 400/1563                   Loss Discriminator: -0.579, loss Generator: 0.519
# Epoch [16/20] Batch 500/1563                   Loss Discriminator: -0.483, loss Generator: 0.594
# Epoch [16/20] Batch 600/1563                   Loss Discriminator: -0.435, loss Generator: -0.121
# Epoch [16/20] Batch 700/1563                   Loss Discriminator: -0.625, loss Generator: 0.409
# Epoch [16/20] Batch 800/1563                   Loss Discriminator: -0.357, loss Generator: 0.058
# Epoch [16/20] Batch 900/1563                   Loss Discriminator: -0.577, loss Generator: -0.031
# Epoch [16/20] Batch 1000/1563                   Loss Discriminator: -0.450, loss Generator: 0.472
# Epoch [16/20] Batch 1100/1563                   Loss Discriminator: -0.571, loss Generator: 0.453
# Epoch [16/20] Batch 1200/1563                   Loss Discriminator: -0.653, loss Generator: 0.467
# Epoch [16/20] Batch 1300/1563                   Loss Discriminator: -0.611, loss Generator: 0.438
# Epoch [16/20] Batch 1400/1563                   Loss Discriminator: -0.499, loss Generator: -0.010
# Epoch [16/20] Batch 1500/1563                   Loss Discriminator: -0.613, loss Generator: 0.538
# Fretchet Distance:  295.78726078345477
# Epoch [17/20] Batch 0/1563                   Loss Discriminator: -0.526, loss Generator: 0.445
# Epoch [17/20] Batch 100/1563                   Loss Discriminator: -0.517, loss Generator: 0.544
# Epoch [17/20] Batch 200/1563                   Loss Discriminator: -0.516, loss Generator: 0.524
# Epoch [17/20] Batch 300/1563                   Loss Discriminator: -0.458, loss Generator: -0.015
# Epoch [17/20] Batch 400/1563                   Loss Discriminator: -0.580, loss Generator: 0.322
# Epoch [17/20] Batch 500/1563                   Loss Discriminator: -0.534, loss Generator: 0.410
# Epoch [17/20] Batch 600/1563                   Loss Discriminator: -0.494, loss Generator: 0.534
# Epoch [17/20] Batch 700/1563                   Loss Discriminator: -0.561, loss Generator: -0.113
# Epoch [17/20] Batch 800/1563                   Loss Discriminator: -0.529, loss Generator: 0.074
# Epoch [17/20] Batch 900/1563                   Loss Discriminator: -0.446, loss Generator: -0.019
# Epoch [17/20] Batch 1000/1563                   Loss Discriminator: -0.517, loss Generator: 0.090
# Epoch [17/20] Batch 1100/1563                   Loss Discriminator: -0.625, loss Generator: 0.309
# Epoch [17/20] Batch 1200/1563                   Loss Discriminator: -0.485, loss Generator: 0.002
# Epoch [17/20] Batch 1300/1563                   Loss Discriminator: -0.461, loss Generator: -0.055
# Epoch [17/20] Batch 1400/1563                   Loss Discriminator: -0.564, loss Generator: 0.306
# Epoch [17/20] Batch 1500/1563                   Loss Discriminator: -0.626, loss Generator: 0.245
# Fretchet Distance:  284.9835270459413
# Epoch [18/20] Batch 0/1563                   Loss Discriminator: -0.626, loss Generator: 0.512
# Epoch [18/20] Batch 100/1563                   Loss Discriminator: -0.574, loss Generator: -0.049
# Epoch [18/20] Batch 200/1563                   Loss Discriminator: -0.365, loss Generator: 0.086
# Epoch [18/20] Batch 300/1563                   Loss Discriminator: -0.476, loss Generator: 0.504
# Epoch [18/20] Batch 400/1563                   Loss Discriminator: -0.628, loss Generator: 0.304
# Epoch [18/20] Batch 500/1563                   Loss Discriminator: -0.454, loss Generator: -0.085
# Epoch [18/20] Batch 600/1563                   Loss Discriminator: -0.530, loss Generator: -0.013
# Epoch [18/20] Batch 700/1563                   Loss Discriminator: -0.593, loss Generator: 0.470
# Epoch [18/20] Batch 800/1563                   Loss Discriminator: -0.563, loss Generator: 0.285
# Epoch [18/20] Batch 900/1563                   Loss Discriminator: -0.428, loss Generator: 0.023
# Epoch [18/20] Batch 1000/1563                   Loss Discriminator: -0.491, loss Generator: -0.036
# Epoch [18/20] Batch 1100/1563                   Loss Discriminator: -0.334, loss Generator: 0.485
# Epoch [18/20] Batch 1200/1563                   Loss Discriminator: -0.439, loss Generator: 0.521
# Epoch [18/20] Batch 1300/1563                   Loss Discriminator: -0.556, loss Generator: 0.464
# Epoch [18/20] Batch 1400/1563                   Loss Discriminator: -0.630, loss Generator: 0.254
# Epoch [18/20] Batch 1500/1563                   Loss Discriminator: -0.528, loss Generator: -0.007
# Fretchet Distance:  293.99303599366243
# Epoch [19/20] Batch 0/1563                   Loss Discriminator: -0.446, loss Generator: -0.070
# Epoch [19/20] Batch 100/1563                   Loss Discriminator: -0.600, loss Generator: 0.323
# Epoch [19/20] Batch 200/1563                   Loss Discriminator: -0.562, loss Generator: 0.450
# Epoch [19/20] Batch 300/1563                   Loss Discriminator: -0.425, loss Generator: 0.491
# Epoch [19/20] Batch 400/1563                   Loss Discriminator: -0.639, loss Generator: 0.567
# Epoch [19/20] Batch 500/1563                   Loss Discriminator: -0.603, loss Generator: 0.403
# Epoch [19/20] Batch 600/1563                   Loss Discriminator: -0.572, loss Generator: 0.564
# Epoch [19/20] Batch 700/1563                   Loss Discriminator: -0.424, loss Generator: -0.199
# Epoch [19/20] Batch 800/1563                   Loss Discriminator: -0.443, loss Generator: -0.035
# Epoch [19/20] Batch 900/1563                   Loss Discriminator: -0.534, loss Generator: -0.128
# Epoch [19/20] Batch 1000/1563                   Loss Discriminator: -0.539, loss Generator: 0.111
# Epoch [19/20] Batch 1100/1563                   Loss Discriminator: -0.481, loss Generator: 0.048
# Epoch [19/20] Batch 1200/1563                   Loss Discriminator: -0.536, loss Generator: -0.005
# Epoch [19/20] Batch 1300/1563                   Loss Discriminator: -0.382, loss Generator: 0.019
# Epoch [19/20] Batch 1400/1563                   Loss Discriminator: -0.556, loss Generator: 0.528
# Epoch [19/20] Batch 1500/1563                   Loss Discriminator: -0.631, loss Generator: 0.276
# Fretchet Distance:  279.4634702915985

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(GenLoss,label="Gen")
plt.plot(DiscLoss,label="Disc")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.savefig('compare.png')
plt.show()

# %%
import pickle
with open('Wgan.pickle', 'wb') as f:
    pickle.dump(fretchet_distances, f)

# %%
file = open('DC_gan.pickle', 'rb')
DC_gan = pickle.load(file)
W_gan = fretchet_distances

# %%
plt.plot(np.arange(1,21), DC_gan, label = 'DCGAN')
plt.plot(np.arange(1,21), W_gan, label = 'WGAN')
plt.xlim(0, 20)
plt.title('Fretchet Distance for 20 epochs')
plt.legend()
plt.show()
