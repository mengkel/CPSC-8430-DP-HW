# %%
import torch
from torch import nn
class generator(nn.Module):

    #generator model
    def __init__(self,in_channels):
        super(generator,self).__init__()
        self.fc1=nn.Linear(in_channels,384)

        self.t1=nn.Sequential(
            nn.ConvTranspose2d(in_channels=384,out_channels=192,kernel_size=(4,4),stride=1,padding=0),
            nn.BatchNorm2d(192),
            nn.ReLU()
        )
        self.t2=nn.Sequential(
            nn.ConvTranspose2d(in_channels=192,out_channels=96,kernel_size=(4,4),stride=2,padding=1),
            nn.BatchNorm2d(96),
            nn.ReLU()
        )
        self.t3=nn.Sequential(
            nn.ConvTranspose2d(in_channels=96,out_channels=48,kernel_size=(4,4),stride=2,padding=1),
            nn.BatchNorm2d(48),
            nn.ReLU()
        )
        self.t4=nn.Sequential(
            nn.ConvTranspose2d(in_channels=48,out_channels=3,kernel_size=(4,4),stride=2,padding=1),
            nn.Tanh()
        )
    
    def forward(self,x):
    	x=x.view(-1,110)
    	x=self.fc1(x)
    	x=x.view(-1,384,1,1)
    	x=self.t1(x)
    	x=self.t2(x)
    	x=self.t3(x)
    	x=self.t4(x)
    	return x #output of generator

# %%
import torch
from torch import nn
class discriminator(nn.Module):
    
    def __init__(self,classes=10):
        #we have 10 classes in the CIFAR dataset with 6000 images per class.
        super(discriminator,self).__init__()
        self.c1=nn.Sequential(
            nn.Conv2d(in_channels=3,out_channels=16,kernel_size=(3,3),stride=2,padding=1),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c2=nn.Sequential(
            nn.Conv2d(in_channels=16,out_channels=32,kernel_size=(3,3),stride=1,padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c3=nn.Sequential(
            nn.Conv2d(in_channels=32,out_channels=64,kernel_size=(3,3),stride=2,padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c4=nn.Sequential(
            nn.Conv2d(in_channels=64,out_channels=128,kernel_size=(3,3),stride=1,padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c5=nn.Sequential(
            nn.Conv2d(in_channels=128,out_channels=256,kernel_size=(3,3),stride=2,padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c6=nn.Sequential(
            nn.Conv2d(in_channels=256,out_channels=512,kernel_size=(3,3),stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.fc_source=nn.Linear(4*4*512,1)
        self.fc_class=nn.Linear(4*4*512,classes)
        self.sig=nn.Sigmoid()
        self.soft=nn.Softmax()

    def forward(self,x):

        x=self.c1(x)
        x=self.c2(x)
        x=self.c3(x)
        x=self.c4(x)
        x=self.c5(x)
        x=self.c6(x)
        x=x.view(-1,4*4*512)
        rf=self.sig(self.fc_source(x))#checks source of the data---i.e.--data generated(fake) or from training set(real)
        c=self.soft(self.fc_class(x))#checks class(label) of data--i.e. to which label the data belongs in the CIFAR10 dataset
        
        return rf,c

# %%
import torch
from torch import nn
import torch.utils.data
import torchvision.datasets as data_set
import torchvision.transforms as transforms
#from model import generator,discriminator
from torch import optim
from torch.autograd import Variable
import numpy as np
import torchvision.utils as vutils

torch.manual_seed(2020)
lr=0.0002
epochs=100
batch_size=100
real_label = torch.FloatTensor(batch_size).cuda()
real_label.fill_(1)

fake_label = torch.FloatTensor(batch_size).cuda()
fake_label.fill_(0)


eval_noise = torch.FloatTensor(batch_size, 110, 1, 1).normal_(0, 1)
eval_noise_ = np.random.normal(0, 1, (batch_size, 110))
eval_label = np.random.randint(0, 10, batch_size)
eval_onehot = np.zeros((batch_size, 10))
eval_onehot[np.arange(batch_size), eval_label] = 1
eval_noise_[np.arange(batch_size), :10] = eval_onehot[np.arange(batch_size)]
eval_noise_ = (torch.from_numpy(eval_noise_))
eval_noise.data.copy_(eval_noise_.view(batch_size, 110, 1, 1))
eval_noise=eval_noise.cuda()


def compute_acc(preds, labels):
	correct = 0
	preds_ = preds.data.max(1)[1]
	correct = preds_.eq(labels.data).cpu().sum()
	acc = float(correct) / float(len(labels.data)) * 100.0
	return acc

def weights_init(m):
		classname = m.__class__.__name__
		if classname.find('Conv') != -1:
			m.weight.data.normal_(0.0, 0.02)
		elif classname.find('BatchNorm') != -1:
			m.weight.data.normal_(1.0, 0.02)
			m.bias.data.fill_(0)

dataset = data_set.CIFAR10(
				root="/home/mengkel/GAN/CIFAR10data", download=False,
				transform=transforms.Compose([
					transforms.Resize((32,32)),
					transforms.ToTensor(),
					transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
					]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
gen=generator(110).cuda()
disc=discriminator().cuda()

gen.apply(weights_init)

optimD=optim.Adam(disc.parameters(),lr)
optimG=optim.Adam(gen.parameters(),lr)

source_obj=nn.BCELoss()#source-loss

class_obj=nn.NLLLoss()#class-loss


for epoch in range(epochs):
	for i,data in enumerate(dataloader,0):
		'''
		At first we will train the discriminator
		'''
		#training with real data----
		optimD.zero_grad()

		image,label=data
		image,label=image.cuda(),label.cuda()
		
		source_,class_=disc(image)#we feed the real images into the discriminator
		#real_label = real_label.unsqueeze(1)
		real_label = real_label.view(batch_size, 1)
		source_error=source_obj(source_,real_label)#label for real images--1; for fake images--0
		class_error=class_obj(class_,label)
		error_real=source_error+class_error
		error_real.backward()
		optimD.step()


		accuracy=compute_acc(class_,label)#getting the current classification accuracy

		#training with fake data now----

		
		noise_ = np.random.normal(0, 1, (batch_size, 110))#generating noise by random sampling from a normal distribution
		
		label=np.random.randint(0,10,batch_size)#generating labels for the entire batch
		
		noise=((torch.from_numpy(noise_)).float())
		noise=noise.cuda()#converting to tensors in order to work with pytorch

		label=((torch.from_numpy(label)).long())
		label=label.cuda()#converting to tensors in order to work with pytorch
		
		noise_image=gen(noise)
		#print(noise_image.size())

		source_,class_=disc(noise_image.detach())#we will be using this tensor later on
		#print(source_.size())
		#fake_label = fake_label.unsqueeze(1)
		fake_label = fake_label.view(batch_size, 1)
		source_error=source_obj(source_,fake_label)#label for real images--1; for fake images--0
		class_error=class_obj(class_,label)
		error_fake=source_error+class_error
		error_fake.backward()
		optimD.step()


		'''
		Now we train the generator as we have finished updating weights of the discriminator
		'''

		gen.zero_grad()
		source_,class_=disc(noise_image)
		source_error=source_obj(source_,real_label)#The generator tries to pass its images as real---so we pass the images as real to the cost function
		class_error=class_obj(class_,label)
		error_gen=source_error+class_error
		error_gen.backward()
		optimG.step()
		iteration_now = epoch * len(dataloader) + i
		if i % 100 == 0:
			print("Epoch--[{} / {}], Loss_Discriminator--[{}], Loss_Generator--[{}],Accuracy--[{}]".format(epoch,epochs,error_fake,error_gen,accuracy))
			print(source_.size())

		'''Saving the images by the epochs'''
		if i % 1000 == 0:
			constructed = gen(eval_noise)
			vutils.save_image(
				constructed.data,
				'%s/results_epoch_%03d.png' % ('GAN/', epoch)
				)
# Out:
# /local_scratch/pbs.536559.pbs02/ipykernel_3550705/4000531231.py:58: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   c=self.soft(self.fc_class(x))#checks class(label) of data--i.e. to which label the data belongs in the CIFAR10 dataset
# Epoch--[0 / 100], Loss_Discriminator--[1.1935075521469116], Loss_Generator--[0.13507509231567383],Accuracy--[8.0]
# torch.Size([100, 1])
# Epoch--[0 / 100], Loss_Discriminator--[0.07251018285751343], Loss_Generator--[3.22395920753479],Accuracy--[19.0]
# torch.Size([100, 1])
# Epoch--[0 / 100], Loss_Discriminator--[0.0037360936403274536], Loss_Generator--[4.1052398681640625],Accuracy--[15.0]
# torch.Size([100, 1])
# Epoch--[0 / 100], Loss_Discriminator--[-0.08677062392234802], Loss_Generator--[4.9274725914001465],Accuracy--[12.0]
# torch.Size([100, 1])
# Epoch--[0 / 100], Loss_Discriminator--[-0.05840592086315155], Loss_Generator--[5.706974029541016],Accuracy--[31.0]
# torch.Size([100, 1])
# Epoch--[1 / 100], Loss_Discriminator--[-0.08029115945100784], Loss_Generator--[6.605209827423096],Accuracy--[14.000000000000002]
# torch.Size([100, 1])
# Epoch--[1 / 100], Loss_Discriminator--[-0.029165230691432953], Loss_Generator--[3.7857775688171387],Accuracy--[17.0]
# torch.Size([100, 1])
# Epoch--[1 / 100], Loss_Discriminator--[-0.08829820156097412], Loss_Generator--[5.550416946411133],Accuracy--[17.0]
# torch.Size([100, 1])
# Epoch--[1 / 100], Loss_Discriminator--[0.0021390169858932495], Loss_Generator--[4.659933567047119],Accuracy--[14.000000000000002]
# torch.Size([100, 1])
# Epoch--[1 / 100], Loss_Discriminator--[0.13719378411769867], Loss_Generator--[4.572697162628174],Accuracy--[26.0]
# torch.Size([100, 1])
# Epoch--[2 / 100], Loss_Discriminator--[-0.06652933359146118], Loss_Generator--[6.785037517547607],Accuracy--[18.0]
# torch.Size([100, 1])
# Epoch--[2 / 100], Loss_Discriminator--[-0.037830900400877], Loss_Generator--[5.858290195465088],Accuracy--[18.0]
# torch.Size([100, 1])
# Epoch--[2 / 100], Loss_Discriminator--[-0.08619950711727142], Loss_Generator--[5.183438301086426],Accuracy--[19.0]
# torch.Size([100, 1])
# Epoch--[2 / 100], Loss_Discriminator--[-0.07452528178691864], Loss_Generator--[4.479434967041016],Accuracy--[27.0]
# torch.Size([100, 1])
# Epoch--[2 / 100], Loss_Discriminator--[-0.02274835854768753], Loss_Generator--[4.906970500946045],Accuracy--[28.000000000000004]
# torch.Size([100, 1])
# Epoch--[3 / 100], Loss_Discriminator--[-0.06909304857254028], Loss_Generator--[8.399666786193848],Accuracy--[18.0]
# torch.Size([100, 1])
# Epoch--[3 / 100], Loss_Discriminator--[1.0043929815292358], Loss_Generator--[2.422597646713257],Accuracy--[25.0]
# torch.Size([100, 1])
# Epoch--[3 / 100], Loss_Discriminator--[0.046856969594955444], Loss_Generator--[5.550084590911865],Accuracy--[23.0]
# torch.Size([100, 1])
# Epoch--[3 / 100], Loss_Discriminator--[-0.06190585717558861], Loss_Generator--[7.633491516113281],Accuracy--[22.0]
# torch.Size([100, 1])
# Epoch--[3 / 100], Loss_Discriminator--[-0.015684857964515686], Loss_Generator--[6.375613212585449],Accuracy--[26.0]
# torch.Size([100, 1])
# Epoch--[4 / 100], Loss_Discriminator--[-0.037493087351322174], Loss_Generator--[2.653635263442993],Accuracy--[18.0]
# torch.Size([100, 1])
# Epoch--[4 / 100], Loss_Discriminator--[-0.09046868979930878], Loss_Generator--[5.6493988037109375],Accuracy--[28.000000000000004]
# torch.Size([100, 1])
# Epoch--[4 / 100], Loss_Discriminator--[-0.14191682636737823], Loss_Generator--[6.708756923675537],Accuracy--[24.0]
# torch.Size([100, 1])
# Epoch--[4 / 100], Loss_Discriminator--[-0.11534629762172699], Loss_Generator--[6.988956451416016],Accuracy--[28.000000000000004]
# torch.Size([100, 1])
# Epoch--[4 / 100], Loss_Discriminator--[-0.1056491807103157], Loss_Generator--[7.419914245605469],Accuracy--[31.0]
# torch.Size([100, 1])
# Epoch--[5 / 100], Loss_Discriminator--[-0.12340234220027924], Loss_Generator--[9.395416259765625],Accuracy--[26.0]
# torch.Size([100, 1])
# Epoch--[5 / 100], Loss_Discriminator--[-0.08546559512615204], Loss_Generator--[6.57050085067749],Accuracy--[32.0]
# torch.Size([100, 1])
# Epoch--[5 / 100], Loss_Discriminator--[-0.1410318911075592], Loss_Generator--[11.43830680847168],Accuracy--[23.0]
# torch.Size([100, 1])
# Epoch--[5 / 100], Loss_Discriminator--[-0.07164198160171509], Loss_Generator--[5.520260334014893],Accuracy--[21.0]
# torch.Size([100, 1])
# Epoch--[5 / 100], Loss_Discriminator--[-0.11281043291091919], Loss_Generator--[12.73575210571289],Accuracy--[35.0]
# torch.Size([100, 1])
# Epoch--[6 / 100], Loss_Discriminator--[-0.059988781809806824], Loss_Generator--[12.666038513183594],Accuracy--[19.0]
# torch.Size([100, 1])
# Epoch--[6 / 100], Loss_Discriminator--[-0.025275301188230515], Loss_Generator--[4.9162821769714355],Accuracy--[31.0]
# torch.Size([100, 1])
# Epoch--[6 / 100], Loss_Discriminator--[0.3255683183670044], Loss_Generator--[4.75582218170166],Accuracy--[25.0]
# torch.Size([100, 1])
# Epoch--[6 / 100], Loss_Discriminator--[0.06231757998466492], Loss_Generator--[5.68385124206543],Accuracy--[33.0]
# torch.Size([100, 1])
# Epoch--[6 / 100], Loss_Discriminator--[-0.10987328737974167], Loss_Generator--[5.340641498565674],Accuracy--[36.0]
# torch.Size([100, 1])
# Epoch--[7 / 100], Loss_Discriminator--[-0.00471092015504837], Loss_Generator--[5.4492974281311035],Accuracy--[26.0]
# torch.Size([100, 1])
# Epoch--[7 / 100], Loss_Discriminator--[-0.08722062408924103], Loss_Generator--[8.682511329650879],Accuracy--[35.0]
# torch.Size([100, 1])
# Epoch--[7 / 100], Loss_Discriminator--[-0.11812039464712143], Loss_Generator--[9.921850204467773],Accuracy--[27.0]
# torch.Size([100, 1])
# Epoch--[7 / 100], Loss_Discriminator--[-0.15265823900699615], Loss_Generator--[6.171311855316162],Accuracy--[27.0]
# torch.Size([100, 1])
# Epoch--[7 / 100], Loss_Discriminator--[0.05678323656320572], Loss_Generator--[5.589232444763184],Accuracy--[36.0]
# torch.Size([100, 1])
# Epoch--
Accuracy--[37.0]
# torch.Size([100, 1])
# Epoch--[84 / 100], Loss_Discriminator--[-0.08225194364786148], Loss_Generator--[5.742961406707764],Accuracy--[56.00000000000001]
# torch.Size([100, 1])
# Epoch--[85 / 100], Loss_Discriminator--[-0.07709504663944244], Loss_Generator--[9.302498817443848],Accuracy--[35.0]
# torch.Size([100, 1])
# Epoch--[85 / 100], Loss_Discriminator--[0.6649072766304016], Loss_Generator--[1.0724493265151978],Accuracy--[41.0]
# torch.Size([100, 1])
# Epoch--[85 / 100], Loss_Discriminator--[0.1896996796131134], Loss_Generator--[3.0890111923217773],Accuracy--[32.0]
# torch.Size([100, 1])
# Epoch--[85 / 100], Loss_Discriminator--[-0.0919933095574379], Loss_Generator--[9.030794143676758],Accuracy--[47.0]
# torch.Size([100, 1])
# Epoch--[85 / 100], Loss_Discriminator--[-0.04432370886206627], Loss_Generator--[6.801609039306641],Accuracy--[56.00000000000001]
# torch.Size([100, 1])
# Epoch--[86 / 100], Loss_Discriminator--[-0.010822288691997528], Loss_Generator--[2.5406174659729004],Accuracy--[37.0]
# torch.Size([100, 1])
# Epoch--[86 / 100], Loss_Discriminator--[-0.06671186536550522], Loss_Generator--[8.062475204467773],Accuracy--[39.0]
# torch.Size([100, 1])
# Epoch--[86 / 100], Loss_Discriminator--[-0.08310253918170929], Loss_Generator--[3.3737056255340576],Accuracy--[36.0]
# torch.Size([100, 1])
# Epoch--[86 / 100], Loss_Discriminator--[-0.08148524165153503], Loss_Generator--[4.745128631591797],Accuracy--[39.0]
# torch.Size([100, 1])
# Epoch--[86 / 100], Loss_Discriminator--[0.3583718538284302], Loss_Generator--[6.350021839141846],Accuracy--[53.0]
# torch.Size([100, 1])
# Epoch--[87 / 100], Loss_Discriminator--[0.32006901502609253], Loss_Generator--[1.977135419845581],Accuracy--[38.0]
# torch.Size([100, 1])
# Epoch--[87 / 100], Loss_Discriminator--[0.0341498963534832], Loss_Generator--[4.759861469268799],Accuracy--[37.0]
# torch.Size([100, 1])
# Epoch--[87 / 100], Loss_Discriminator--[0.0839163213968277], Loss_Generator--[4.472819805145264],Accuracy--[36.0]
# torch.Size([100, 1])
# Epoch--[87 / 100], Loss_Discriminator--[0.03935958445072174], Loss_Generator--[3.2225728034973145],Accuracy--[41.0]
# torch.Size([100, 1])
# Epoch--[87 / 100], Loss_Discriminator--[-0.007354751229286194], Loss_Generator--[1.378232717514038],Accuracy--[55.00000000000001]
# torch.Size([100, 1])
# Epoch--[88 / 100], Loss_Discriminator--[0.16606391966342926], Loss_Generator--[4.134278297424316],Accuracy--[34.0]
# torch.Size([100, 1])
# Epoch--[88 / 100], Loss_Discriminator--[0.0840945765376091], Loss_Generator--[2.6959850788116455],Accuracy--[40.0]
# torch.Size([100, 1])
# Epoch--[88 / 100], Loss_Discriminator--[-0.06012992560863495], Loss_Generator--[6.367406845092773],Accuracy--[46.0]
# torch.Size([100, 1])
# Epoch--[88 / 100], Loss_Discriminator--[-0.0179084911942482], Loss_Generator--[4.868983745574951],Accuracy--[41.0]
# torch.Size([100, 1])
# Epoch--[88 / 100], Loss_Discriminator--[-0.012811945751309395], Loss_Generator--[4.791445732116699],Accuracy--[52.0]
# torch.Size([100, 1])
# Epoch--[89 / 100], Loss_Discriminator--[0.5054640173912048], Loss_Generator--[1.0794403553009033],Accuracy--[42.0]
# torch.Size([100, 1])
# Epoch--[89 / 100], Loss_Discriminator--[-0.04962006211280823], Loss_Generator--[6.423192977905273],Accuracy--[37.0]
# torch.Size([100, 1])
# Epoch--[89 / 100], Loss_Discriminator--[0.04894675314426422], Loss_Generator--[2.924330949783325],Accuracy--[35.0]
# torch.Size([100, 1])
# Epoch--[89 / 100], Loss_Discriminator--[-0.047471001744270325], Loss_Generator--[0.926521897315979],Accuracy--[47.0]
# torch.Size([100, 1])
# Epoch--[89 / 100], Loss_Discriminator--[-0.060613106936216354], Loss_Generator--[9.818429946899414],Accuracy--[53.0]
# torch.Size([100, 1])
# Epoch--[90 / 100], Loss_Discriminator--[-0.09607816487550735], Loss_Generator--[4.018042087554932],Accuracy--[42.0]
# torch.Size([100, 1])
# Epoch--[90 / 100], Loss_Discriminator--[0.0328713059425354], Loss_Generator--[5.480602741241455],Accuracy--[40.0]
# torch.Size([100, 1])
# Epoch--[90 / 100], Loss_Discriminator--[0.4372957646846771], Loss_Generator--[4.5156073570251465],Accuracy--[32.0]
# torch.Size([100, 1])
# Epoch--[90 / 100], Loss_Discriminator--[0.018037185072898865], Loss_Generator--[5.120538711547852],Accuracy--[40.0]
# torch.Size([100, 1])
# Epoch--[90 / 100], Loss_Discriminator--[0.3359903395175934], Loss_Generator--[1.7780593633651733],Accuracy--[50.0]
# torch.Size([100, 1])
# Epoch--[91 / 100], Loss_Discriminator--[0.088849738240242], Loss_Generator--[2.3111772537231445],Accuracy--[43.0]
# torch.Size([100, 1])
# Epoch--[91 / 100], Loss_Discriminator--[-0.0635804682970047], Loss_Generator--[7.6336822509765625],Accuracy--[37.0]
# torch.Size([100, 1])
# Epoch--[91 / 100], Loss_Discriminator--[-0.016368471086025238], Loss_Generator--[5.246509075164795],Accuracy--[40.0]
# torch.Size([100, 1])
# Epoch--[91 / 100], Loss_Discriminator--[0.08331866562366486], Loss_Generator--[0.9394792318344116],Accuracy--[38.0]
# torch.Size([100, 1])
# Epoch--[91 / 100], Loss_Discriminator--[-0.13640150427818298], Loss_Generator--[2.758894920349121],Accuracy--[51.0]
# torch.Size([100, 1])
# Epoch--[92 / 100], Loss_Discriminator--[-0.06735925376415253], Loss_Generator--[5.647300720214844],Accuracy--[38.0]
# torch.Size([100, 1])
# Epoch--[92 / 100], Loss_Discriminator--[-0.06544219702482224], Loss_Generator--[7.414383411407471],Accuracy--[35.0]
# torch.Size([100, 1])
# Epoch--[92 / 100], Loss_Discriminator--[0.026995785534381866], Loss_Generator--[3.901538133621216],Accuracy--[36.0]
# torch.Size([100, 1])
# Epoch--[92 / 100], Loss_Discriminator--[0.49336081743240356], Loss_Generator--[2.6179702281951904],Accuracy--[40.0]
# torch.Size([100, 1])
# Epoch--[92 / 100], Loss_Discriminator--[-0.07967733591794968], Loss_Generator--[10.143209457397461],Accuracy--[51.0]
# torch.Size([100, 1])
# Epoch--[93 / 100], Loss_Discriminator--[-0.10806513577699661], Loss_Generator--[5.924168586730957],Accuracy--[38.0]
# torch.Size([100, 1])
# Epoch--[93 / 100], Loss_Discriminator--[0.2076944261789322], Loss_Generator--[2.9160726070404053],Accuracy--[40.0]
# torch.Size([100, 1])
# Epoch--[93 / 100], Loss_Discriminator--[1.0982742309570312], Loss_Generator--[1.1898001432418823],Accuracy--[31.0]
# torch.Size([100, 1])
# Epoch--[93 / 100], Loss_Discriminator--[-0.06762741506099701], Loss_Generator--[6.332216262817383],Accuracy--[43.0]
# torch.Size([100, 1])
# Epoch--[93 / 100], Loss_Discriminator--[1.1949198246002197], Loss_Generator--[6.115547180175781],Accuracy--[54.0]
# torch.Size([100, 1])
# Epoch--[94 / 100], Loss_Discriminator--[0.1626814752817154], Loss_Generator--[1.6066747903823853],Accuracy--[36.0]
# torch.Size([100, 1])
# Epoch--[94 / 100], Loss_Discriminator--[1.2713711261749268], Loss_Generator--[0.7900795936584473],Accuracy--[37.0]
# torch.Size([100, 1])
# Epoch--[94 / 100], Loss_Discriminator--[0.055637333542108536], Loss_Generator--[7.164524078369141],Accuracy--[38.0]
# torch.Size([100, 1])
# Epoch--[94 / 100], Loss_Discriminator--[-0.0012907609343528748], Loss_Generator--[3.4921839237213135],Accuracy--[45.0]
# torch.Size([100, 1])
# Epoch--[94 / 100], Loss_Discriminator--[-0.017362534999847412], Loss_Generator--[3.967679500579834],Accuracy--[51.0]
# torch.Size([100, 1])
# Epoch--[95 / 100], Loss_Discriminator--[0.02072279155254364], Loss_Generator--[3.8398783206939697],Accuracy--[35.0]
# torch.Size([100, 1])
# Epoch--[95 / 100], Loss_Discriminator--[0.3766334056854248], Loss_Generator--[1.349310278892517],Accuracy--[39.0]
# torch.Size([100, 1])
# Epoch--[95 / 100], Loss_Discriminator--[0.027496136724948883], Loss_Generator--[3.687662124633789],Accuracy--[36.0]
# torch.Size([100, 1])
# Epoch--[95 / 100], Loss_Discriminator--[-0.051038533449172974], Loss_Generator--[4.967988967895508],Accuracy--[49.0]
# torch.Size([100, 1])
# Epoch--[95 / 100], Loss_Discriminator--[-0.048520442098379135], Loss_Generator--[2.2108511924743652],Accuracy--[53.0]
# torch.Size([100, 1])
# Epoch--[96 / 100], Loss_Discriminator--[-0.1183725893497467], Loss_Generator--[6.307288646697998],Accuracy--[42.0]
# torch.Size([100, 1])
# Epoch--[96 / 100], Loss_Discriminator--[0.6351482272148132], Loss_Generator--[3.0157222747802734],Accuracy--[39.0]
# torch.Size([100, 1])
# Epoch--[96 / 100], Loss_Discriminator--[-0.11129126697778702], Loss_Generator--[3.157130718231201],Accuracy--[37.0]
# torch.Size([100, 1])
# Epoch--[96 / 100], Loss_Discriminator--[0.3560539484024048], Loss_Generator--[3.3218679428100586],Accuracy--[41.0]
# torch.Size([100, 1])
# Epoch--[96 / 100], Loss_Discriminator--[0.2852284908294678], Loss_Generator--[3.8920352458953857],Accuracy--[50.0]
# torch.Size([100, 1])
# Epoch--[97 / 100], Loss_Discriminator--[0.09328729659318924], Loss_Generator--[5.581031322479248],Accuracy--[42.0]
# torch.Size([100, 1])
# Epoch--[97 / 100], Loss_Discriminator--[-0.03683813661336899], Loss_Generator--[0.3509613871574402],Accuracy--[37.0]
# torch.Size([100, 1])
# Epoch--[97 / 100], Loss_Discriminator--[-0.10465992987155914], Loss_Generator--[8.032752990722656],Accuracy--[38.0]
# torch.Size([100, 1])
# Epoch--[97 / 100], Loss_Discriminator--[-0.09026453644037247], Loss_Generator--[4.577341556549072],Accuracy--[46.0]
# torch.Size([100, 1])
# Epoch--[97 / 100], Loss_Discriminator--[-0.13379833102226257], Loss_Generator--[8.777970314025879],Accuracy--[52.0]
# torch.Size([100, 1])
# Epoch--[98 / 100], Loss_Discriminator--[8.27498733997345e-05], Loss_Generator--[3.946467638015747],Accuracy--[41.0]
# torch.Size([100, 1])
# Epoch--[98 / 100], Loss_Discriminator--[-0.05457739531993866], Loss_Generator--[3.460380792617798],Accuracy--[36.0]
# torch.Size([100, 1])
# Epoch--[98 / 100], Loss_Discriminator--[1.4848496913909912], Loss_Generator--[1.483776330947876],Accuracy--[35.0]
# torch.Size([100, 1])
# Epoch--[98 / 100], Loss_Discriminator--[0.31632500886917114], Loss_Generator--[3.223790168762207],Accuracy--[51.0]
# torch.Size([100, 1])
# Epoch--[98 / 100], Loss_Discriminator--[0.4044743478298187], Loss_Generator--[2.1595871448516846],Accuracy--[50.0]
# torch.Size([100, 1])
# Epoch--[99 / 100], Loss_Discriminator--[-0.03898940235376358], Loss_Generator--[2.577442169189453],Accuracy--[38.0]
# torch.Size([100, 1])
# Epoch--[99 / 100], Loss_Discriminator--[0.40428757667541504], Loss_Generator--[2.3913302421569824],Accuracy--[42.0]
# torch.Size([100, 1])
# Epoch--[99 / 100], Loss_Discriminator--[0.3982170522212982], Loss_Generator--[0.9210497140884399],Accuracy--[40.0]
# torch.Size([100, 1])
# Epoch--[99 / 100], Loss_Discriminator--[1.2844427824020386], Loss_Generator--[2.170646905899048],Accuracy--[41.0]
# torch.Size([100, 1])
# Epoch--[99 / 100], Loss_Discriminator--[0.20937153697013855], Loss_Generator--[4.141229152679443],Accuracy--[52.0]
# torch.Size([100, 1])
